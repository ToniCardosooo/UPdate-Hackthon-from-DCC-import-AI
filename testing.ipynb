# %%
import pandas as pd

df = pd.read_csv("video_games.csv")

df
# Out:
# d:\anaconda\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#         id                                               name   category  \
# 0     1020                                 Grand Theft Auto V  main_game
# 1     1942                           The Witcher 3: Wild Hunt  main_game
# 2      472                        The Elder Scrolls V: Skyrim  main_game
# 3       72                                           Portal 2  main_game
# 4       71                                             Portal  main_game
# ...    ...                                                ...        ...
# 5819   721                    Freedom Force vs. The 3rd Reich  main_game
# 5820   682                              Europa Universalis II  main_game
# 5821   628                 Championship Manager: Season 03/04  main_game
# ...
